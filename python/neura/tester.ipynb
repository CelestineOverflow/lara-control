# %%
import cv2
img_path = r'C:\Labhandler\cobot\static\icon.jpg'
img = cv2.imread(img_path, cv2.IMREAD_COLOR)

cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import requests
import json


bearer = "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI2NjFhODIyNDY1MWJlNjFlNzQyZDhhNzUiLCJpYXQiOjE3Mjc3OTE3NjN9.unaSPlaTMy63bA9PB3Jx2nMvUvpc7SFCJBJ-A6KPXAg"
# ----------------------
# Define the API endpoint and payload
api_endpoint = "http://192.168.2.13:8081/api/joint"
payload = json.loads(r'''
{
        "RobotSettings": {
            "encoderOffset": {
                "A1": 10718404,
                "A2": 15281699,
                "A3": 2039511,
                "A4": 1169205,
                "A5": 2450360,
                "A6": 13326737
            },
            "minLimit": {
                "A1": -3.1415926,
                "A2": -3.1415926,
                "A3": -2.6179938,
                "A4": -3.1415926,
                "A5": -3.1415926,
                "A6": -3.1415926
            },
            "maxLimit": {
                "A1": 3.1415926,
                "A2": 3.1415926,
                "A3": 2.6179938,
                "A4": 3.1415926,
                "A5": 3.1415926,
                "A6": 3.1415926
            },
            "jogVelocity": {
                "Va1": 1.7453292519943295,
                "Va2": 1.7453292519943295,
                "Va3": 1.7453292519943295,
                "Va4": 1.7453292519943295,
                "Va5": 1.7453292519943295,
                "Va6": 1.7453292519943295
            },
            "zeroG": {
                "gravityCompensation": {
                    "a1": 0,
                    "a2": 0,
                    "a3": 0,
                    "a4": 0,
                    "a5": 0,
                    "a6": 0,
                    "a7": 0
                },
                "frictionCompensation": {
                    "a1": 0,
                    "a2": 0,
                    "a3": 0,
                    "a4": 0,
                    "a5": 0,
                    "a6": 0,
                    "a7": 0
                }
            },
            "collision": {
                "a1": 0,
                "a2": 0,
                "a3": 0,
                "a4": 0,
                "a5": 0,
                "a6": 0
            }
        },
        "safetySettings": {
            "maxVelHardStop": {
                "Va1": 0,
                "Va2": 0,
                "Va3": 0,
                "Va4": 0,
                "Va5": 0,
                "Va6": 0
            },
            "jointMinTorque": {
                "Ma1": 0,
                "Ma2": 0,
                "Ma3": 0,
                "Ma4": 0,
                "Ma5": 0,
                "Ma6": 0
            },
            "jointMaxTorque": {
                "Ma1": 0,
                "Ma2": 0,
                "Ma3": 0,
                "Ma4": 0,
                "Ma5": 0,
                "Ma6": 0
            }
        },
        "angularVelocity": 0.524
}
''')
# Define the headers with the authorization token
headers = {
    "Authorization": bearer
}

# Send the POST request with headers
response = requests.get(api_endpoint, json=payload, headers=headers)

# Print the response
print(response.status_code)
print(response.json())
# ----------------------
# Define the API endpoint and payload
api_endpoint = "http://192.168.2.13:8081/api/manjoint"

payload = {
    "A1": 2.094395,
    "A2": 0,
    "A3": 0,
    "A4": 0,
    "A5": 0,
    "A6": 0
}

# Define the headers with the authorization token
headers = {
    "Authorization": bearer
}

# Send the POST request with headers
response = requests.post(api_endpoint, json=payload, headers=headers)

# Print the response
print(response.status_code)
print(response.json())
# Out:
# 200
# [{'RobotSettings': {'encoderOffset': {'A1': 10718404, 'A2': 15281699, 'A3': 2039511, 'A4': 1169205, 'A5': 2450360, 'A6': 13326737}, 'minLimit': {'A1': -3.1415926, 'A2': -3.1415926, 'A3': -2.6179938, 'A4': -3.1415926, 'A5': -3.1415926, 'A6': -3.1415926}, 'maxLimit': {'A1': 3.1415926, 'A2': 3.1415926, 'A3': 2.6179938, 'A4': 3.1415926, 'A5': 3.1415926, 'A6': 3.1415926}, 'jogVelocity': {'Va1': 1.7453292519943295, 'Va2': 1.7453292519943295, 'Va3': 1.7453292519943295, 'Va4': 1.7453292519943295, 'Va5': 1.7453292519943295, 'Va6': 1.7453292519943295}, 'zeroG': {'gravityCompensation': {'a1': 0, 'a2': 0, 'a3': 0, 'a4': 0, 'a5': 0, 'a6': 0, 'a7': 0}, 'frictionCompensation': {'a1': 0, 'a2': 0, 'a3': 0, 'a4': 0, 'a5': 0, 'a6': 0, 'a7': 0}}, 'collision': {'a1': 0, 'a2': 0, 'a3': 0, 'a4': 0, 'a5': 0, 'a6': 0}}, 'safetySettings': {'maxVelHardStop': {'Va1': 0, 'Va2': 0, 'Va3': 0, 'Va4': 0, 'Va5': 0, 'Va6': 0}, 'jointMinTorque': {'Ma1': 0, 'Ma2': 0, 'Ma3': 0, 'Ma4': 0, 'Ma5': 0, 'Ma6': 0}, 'jointMaxTorque': {'Ma1': 0, 'Ma2': 0, 'Ma3': 0, 'Ma4': 0, 'Ma5': 0, 'Ma6': 0}}, 'angularVelocity': 0.524, 'DOF': 6, 'toggleGotoPoint': True, 'overRide': 100, 'incOnOff': False, 'multiturn': False, 'incrementMovement': 0, '_id': '661a8225651be61e742d8a92', '__v': 0}]
# 201
# {'A1': 2.094395, 'A2': 0, 'A3': 0, 'A4': 0, 'A5': 0, 'A6': 0, '_id': '671bbb5a098b28072582cae9', '__v': 0}

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 17
#      14     with SocketIO('192.168.2.13', 8081, LoggingNamespace) as socketIO:
#      15         socketIO.emit('linearveltrigger', {'data': True})
# ---> 17 asyncio.run(main())
#
# File c:\Users\nxp84358\AppData\Local\Programs\Python\Python311\Lib\asyncio\runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
