# %%
from neurapy.robot import Robot
r = Robot()
print(r.robot_name)
print(r.dof)
print(r.platform)
print(r.payload)
print(r.kURL)
print(r.robot_urdf_path)
print(r.current_tool)
print(r.connection)
print(r.version)
# print(r.robot_status())
#11038693.0

encoder_ticks = r.robot_status('loadSideEncValue')
for i in encoder_ticks:
    print(f'Encoder ticks: {i}')

last_joint_val = 13326737

encoder_ticks[-1] = last_joint_val


joint_angles = r.encoder2rad(encoder_ticks)

def rad2deg(rad):
    return rad*180/3.14159
for i in joint_angles:
    print(rad2deg(i))

# %%
import math
from neurapy.robot import Robot

r = Robot()
linear_property = {
    "speed": 0.1,
    "acceleration": 1.0,
    "jerk": 1000.0,
    "rotation_speed": 1.5,
    "rotation_acceleration": 10.0,
    "rotation_jerk": 1000.0,
    "weaving": False,
    "enable_blending": False,
    "offset_frame": "Tool",
    "cartesian_offset": [0.0, 0.0, -0.01, 0.0, 0.0, 0.0],
    "stored_id": 1,
    "current_joint_angles": r.get_current_joint_angles()
}
plan_id = r.plan_move_linear_relative(**linear_property)
execute = r.executor([plan_id])
r.stop()  # only needs to be executed at the end of the program

# for i in range(10):
    # linear_property = {
    #     "speed": 0.1,
    #     "acceleration": 1.0,
    #     "jerk": 10.0,
    #     "rotation_speed": 1.5,
    #     "rotation_acceleration": 10.0,
    #     "rotation_jerk": 1000.0,
    #     "weaving": False,
    #     "enable_blending": True,
    #     "offset_frame": "Tool",
    #     "cartesian_offset": [0.0, 0.0, 0.01, 0.0, 0.0, 0.0],
    #     "stored_id": 1,
    #     "current_joint_angles": r.get_current_joint_angles()
    # }
    # plan_id = r.plan_move_linear_relative(**linear_property)
    # execute = r.executor([plan_id])
    # r.stop()  # only needs to be executed at the end of the progra
# Out:
# [2025-02-20 19:10:16][neurapy_logger][WARNING] : Current client version is not compatiable with the version of the server running on the robot. Some of the functionlities specified in the documentation might not work in the intended way. Please upgrade to the correct version .Client Version : {VERSION},Server Version : {self.version} :(robot.py:209)

# %%
from neurapy.robot import Robot
robot = Robot()
import logging
import time
#show all log messages
logging.basicConfig(level=logging.NOTSET)

for j in range(10):
    direction = 1 if j % 2 == 0 else -1
    robot.turn_on_jog(
        jog_velocity=[0, 0, direction, 0, 0, 0],
        jog_type='Cartesian'
    )
    robot.jog(set_jogging_external_flag=1)
    t = 0
    while t < 100:
        robot.jog(set_jogging_external_flag=1)
        t += 1
    robot.turn_off_jog()
    robot.unpause()
# Out:
# [2025-02-20 19:16:07][neurapy_logger][INFO] : initialize_attributes called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:07][neurapy_logger][INFO] : Robot initialized with following functions ['move_joint', 'move_linear', 'move_circular', 'move_composite', 'record_path', 'power', 'zero_g', 'io', 'set_tool', 'gripper', 'wait', 'override', 'pause', 'unpause', 'stop', 'ik_fk', 'robot_status', 'program_status', 'get_point', 'initialize_attributes', 'set_mode', 'motion_status', 'get_mode', 'get_zerog_status', 'rpy_to_quaternion', 'quaternion_to_rpy', 'get_tcp_pose', 'get_reference_frame', 'get_doc', 'get_reference_frame_with_offset', 'set_encoder_offsets', 'set_opcua_msg', 'turn_on_jog', 'turn_off_jog', 'jog', 'read_safeio', 'get_encoder_offsets', 'get_sim_or_real', 'move_linear_from_current_position', 'get_tools', 'get_encoder_offsets', 'set_sim_real', 'reset_error', 'get_diagnostics', 'get_errors', 'get_warnings', 'wait', 'wait_for_digital_input', 'wait_for_digital_input_timer_on_delay', 'wait_for_digital_input_timer_off_delay', 'wait_for_analog_input', 'wait_for_tool_digital_input', 'wait_for_tool_digital_input_timer_on_delay', 'wait_for_tool_digital_input_timer_off_delay', 'wait_for_tool_analog_input', 'set_linear_speed', 'get_linear_speed', 'disable_collision_detection', 'disable_reflex', 'enable_collision_detection', 'enable_reflex', 'encoder2rad', 'get_tcp_pose_quaternion', 'get_current_joint_torques', 'is_robot_in_automatic_mode', 'is_robot_in_collision', 'is_robot_in_semi_automatic_mode', 'is_robot_in_simulation', 'is_robot_in_teach_mode', 'motion_status', 'move_linear_relative', 'quaternion_to_rpy', 'rpy_to_quaternion', 'set_joint_speed', 'set_linear_acceleration', 'set_current_position_as_zero', 'get_current_load_side_encoder_values', 'get_current_load_side_encoder2rade_values', 'get_current_cartesian_pose', 'get_tcp_pose_quaternion', 'quaternion_to_rpy', 'program_status', 'compute_inverse_kinematics', 'get_flange_pose_quaternion', 'get_tool_flange_pose', 'plan_move_linear_relative', 'get_current_joint_angles', 'executor'] and robot version v4.18.1 :(robot.py:207)
# [2025-02-20 19:16:07][neurapy_logger][WARNING] : Current client version is not compatiable with the version of the server running on the robot. Some of the functionlities specified in the documentation might not work in the intended way. Please upgrade to the correct version .Client Version : {VERSION},Server Version : {self.version} :(robot.py:209)
# [2025-02-20 19:16:07][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:07][neurapy_logger][INFO] : turn_on_jog called with args (), {'jog_velocity': [0, 0, 1, 0, 0, 0], 'jog_type': 'Cartesian'} :(robot.py:88)
# [2025-02-20 19:16:07][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:07][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:07][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:08][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : turn_off_jog called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : unpause called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : turn_on_jog called with args (), {'jog_velocity': [0, 0, -1, 0, 0, 0], 'jog_type': 'Cartesian'} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:09][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:10][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : turn_off_jog called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : unpause called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : turn_on_jog called with args (), {'jog_velocity': [0, 0, 1, 0, 0, 0], 'jog_type': 'Cartesian'} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:11][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : turn_off_jog called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:16:12][neurapy_logger][INFO] : unpause called with args (), {} :(robot.py:88)
# ...
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:45][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : turn_off_jog called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : unpause called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : turn_on_jog called with args (), {'jog_velocity': [0, 0, 1, 0, 0, 0], 'jog_type': 'Cartesian'} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : get_diagnostics called with args (), {} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)
# [2025-02-20 19:17:46][neurapy_logger][INFO] : jog called with args (), {'set_jogging_external_flag': 1} :(robot.py:88)

# %%
from neurapy.robot import Robot
r = Robot()
flange_pose_quaternion = r.get_flange_pose_quaternion()
print(flange_pose_quaternion)
# Out:
# [2025-02-20 11:44:10][neurapy_logger][WARNING] : Current client version is not compatiable with the version of the server running on the robot. Some of the functionlities specified in the documentation might not work in the intended way. Please upgrade to the correct version .Client Version : {VERSION},Server Version : {self.version} :(robot.py:206)
# [-0.12733140331528603, 0.49060943569143606, 0.23022473054813802, 7.583607549655399e-06, 0.9999992495599631, 0.0002715422308841214, -0.0011946073900859714]
# [2025-02-20 14:23:40][neurapy_logger][ERROR] : {'critical': True, 'issues': {'collision_detected': False, 'other_errors': ['Error Emergency Pressed or not resetted. Please release all Emergency PB  and press illuminated white PB on control box. It should glow white. Then press reset on HMI'], 'powered_off': False}} :(robot.py:220)
# Exception in thread Thread-5 (notify_diagnostics):
# Traceback (most recent call last):
#   File "c:\Users\nxp84358\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\nxp84358\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\nxp84358\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\nxp84358\Documents\GitHub\lara-control\python\neura\neurapy\robot.py", line 215, in notify_diagnostics
#     diagnostics = self.get_diagnostics()
#                   ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nxp84358\Documents\GitHub\lara-control\python\neura\neurapy\robot.py", line 93, in wrapped_function
#     response = json.loads(new_data.decode("utf-8"))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nxp84358\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nxp84358\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\nxp84358\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
print(13326737-11038693)
print(13326737+2288044)

# %%
import cv2
img_path = r'C:\Labhandler\cobot\static\icon.jpg'
img = cv2.imread(img_path, cv2.IMREAD_COLOR)

cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import requests
import json


bearer = "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI2NjFhODIyNDY1MWJlNjFlNzQyZDhhNzUiLCJpYXQiOjE3Mjc3OTE3NjN9.unaSPlaTMy63bA9PB3Jx2nMvUvpc7SFCJBJ-A6KPXAg"
# ----------------------
# Define the API endpoint and payload
api_endpoint = "http://192.168.2.13:8081/api/joint"
payload = json.loads(r'''
{
        "RobotSettings": {
            "encoderOffset": {
                "A1": 10718404,
                "A2": 15281699,
                "A3": 2039511,
                "A4": 1169205,
                "A5": 2450360,
                "A6": 13326737
            },
            "minLimit": {
                "A1": -3.1415926,
                "A2": -3.1415926,
                "A3": -2.6179938,
                "A4": -3.1415926,
                "A5": -3.1415926,
                "A6": -3.1415926
            },
            "maxLimit": {
                "A1": 3.1415926,
                "A2": 3.1415926,
                "A3": 2.6179938,
                "A4": 3.1415926,
                "A5": 3.1415926,
                "A6": 3.1415926
            },
            "jogVelocity": {
                "Va1": 1.7453292519943295,
                "Va2": 1.7453292519943295,
                "Va3": 1.7453292519943295,
                "Va4": 1.7453292519943295,
                "Va5": 1.7453292519943295,
                "Va6": 1.7453292519943295
            },
            "zeroG": {
                "gravityCompensation": {
                    "a1": 0,
                    "a2": 0,
                    "a3": 0,
                    "a4": 0,
                    "a5": 0,
                    "a6": 0,
                    "a7": 0
                },
                "frictionCompensation": {
                    "a1": 0,
                    "a2": 0,
                    "a3": 0,
                    "a4": 0,
                    "a5": 0,
                    "a6": 0,
                    "a7": 0
                }
            },
            "collision": {
                "a1": 0,
                "a2": 0,
                "a3": 0,
                "a4": 0,
                "a5": 0,
                "a6": 0
            }
        },
        "safetySettings": {
            "maxVelHardStop": {
                "Va1": 0,
                "Va2": 0,
                "Va3": 0,
                "Va4": 0,
                "Va5": 0,
                "Va6": 0
            },
            "jointMinTorque": {
                "Ma1": 0,
                "Ma2": 0,
                "Ma3": 0,
                "Ma4": 0,
                "Ma5": 0,
                "Ma6": 0
            },
            "jointMaxTorque": {
                "Ma1": 0,
                "Ma2": 0,
                "Ma3": 0,
                "Ma4": 0,
                "Ma5": 0,
                "Ma6": 0
            }
        },
        "angularVelocity": 0.524
}
''')
# Define the headers with the authorization token
headers = {
    "Authorization": bearer
}

# Send the POST request with headers
response = requests.get(api_endpoint, json=payload, headers=headers)

# Print the response
print(response.status_code)
print(response.json())
# ----------------------
# Define the API endpoint and payload
api_endpoint = "http://192.168.2.13:8081/api/manjoint"

payload = {
    "A1": 2.094395,
    "A2": 0,
    "A3": 0,
    "A4": 0,
    "A5": 0,
    "A6": 0
}

# Define the headers with the authorization token
headers = {
    "Authorization": bearer
}

# Send the POST request with headers
response = requests.post(api_endpoint, json=payload, headers=headers)

# Print the response
print(response.status_code)
print(response.json())

# %%
from neurapy.robot import Robot
import time

robot = Robot()
robot.turn_on_jog(
    jog_velocity=[0, 0, 1, 0, 0, 0], 
    jog_type='Cartesian'
)
robot.jog(set_jogging_external_flag = 1)
i = 0
start = time.time()
while(i < 1000):
    robot.jog(set_jogging_external_flag = 1)
    i += 1
    elapsed_time = (time.time() - start) * 1000  # Convert to milliseconds
    print(f"Iteration {i}: {elapsed_time:.2f} ms")
    start = time.time()
robot.turn_off_jog()

# %%
from neurapy.robot import Robot
r = Robot()
print(r.robot_name)
print(r.dof)
print(r.platform)
print(r.payload)
print(r.kURL)
print(r.robot_urdf_path)
print(r.current_tool)
print(r.connection)
print(r.version)
pose = r.get_tcp_pose_quaternion()
#last 4 values are quaternion
quat = pose[-4:]
rpy = r.quaternion_to_rpy(quat[0], quat[1], quat[2], quat[3])
pose = pose[:-4]
pose.extend(rpy)
# get current cartesian position


linear_property = {
 "speed": 0.008,
 "acceleration": 1.0,
 "blend_radius": 0.005,
 "target_pose": [
   
    [
            pose[0],
            pose[1],
            pose[2],
            pose[3],
            pose[4],
            pose[5]
    ],
    [
            pose[0],
            pose[1],
            pose[2] + 0.01,
            pose[3],
            pose[4],
            pose[5]
    ],
 ],
 "current_joint_angles":r.robot_status("jointAngles"),
 "weaving":True,
 "pattern": 1,
 "amplitude": 0.006,
 "amplitude_left": 0.0,
 "amplitude_right": 0.0,
 "frequency": 1.5,
 "dwell_time_left": 0.0,
 "dwell_time_right": 0.0,
 "elevation": 0.0,
 "azimuth": 0.0
 }
r.move_linear(**linear_property)
r.stop()
